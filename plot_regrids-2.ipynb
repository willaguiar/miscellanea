# %%
# Plotting regridded outputs

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import netCDF4
import numpy as np
import scipy as sp
import cosima_cookbook as cc
import scipy as sp
import matplotlib.pyplot as plt
import cartopy.crs as ccrs
import os
import xarray as xr
from scipy.interpolate import griddata
import scipy.interpolate.ndgriddata as ndgriddata
from dask.distributed import Client
import xesmf

# %%
grid005_BF = xr.open_dataset('/g/data/x77/ahg157/inputs/mom6/panan/forcing_obc_shifted.nc')
grid40th=xr.open_dataset('/g/data/x77/wf4500/forcing_final_140th.nc')

# %%
grid005_BF,grid40th
# Out:
# (<xarray.Dataset>
#  Dimensions:              (time: 365, nz_segment_001_temp: 75,
#                            ny_segment_001: 1, nx_segment_001: 14401,
#                            nz_segment_001_salt: 75, nz_segment_001_u: 75,
#                            nz_segment_001_v: 75)
#  Coordinates:
#    * ny_segment_001       (ny_segment_001) int32 0
#    * nx_segment_001       (nx_segment_001) int32 0 1 2 3 ... 14398 14399 14400
#    * nz_segment_001_temp  (nz_segment_001_temp) int32 0 1 2 3 4 ... 71 72 73 74
#    * nz_segment_001_salt  (nz_segment_001_salt) int32 0 1 2 3 4 ... 71 72 73 74
#    * nz_segment_001_u     (nz_segment_001_u) int32 0 1 2 3 4 5 ... 70 71 72 73 74
#    * nz_segment_001_v     (nz_segment_001_v) int32 0 1 2 3 4 5 ... 70 71 72 73 74
#    * time                 (time) object 1900-01-01 12:00:00 ... 1900-12-31 12:...
#  Data variables:
#      temp_segment_001     (time, nz_segment_001_temp, ny_segment_001, nx_segment_001) float64 ...
# ...

# %%
plt.subplot(2,1, 1)
grid005_BF['temp_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['temp_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['salt_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['salt_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['dz_u_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['dz_u_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['eta_t_segment_001'].plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['eta_t_segment_001'].plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['dz_v_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['dz_v_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['v_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['v_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['u_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['u_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['dz_temp_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['dz_temp_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['dz_salt_segment_001'].mean(dim='time').plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['dz_salt_segment_001'].mean(dim='time').plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['ilist_segment_001'].plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['ilist_segment_001'].plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')

# %%
plt.subplot(2,1, 1)
grid005_BF['jlist_segment_001'].plot()
plt.title('1/20th')
plt.subplot(2,1, 2)
grid40th['jlist_segment_001'].plot()
plt.title('1/40th')
# Out:
# Text(0.5, 1.0, '1/40th')
